# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### 👨‍🏫👩‍🏫 Cuerpo Docente:
#
# - Profesor: Sebastián Tinoco, Stefano Schiappacasse
# - Auxiliar: Melanie Peña Torres, Valentina Rojas Osorio
# - Ayudante: Valentina Zuñiga, Ángelo Muñoz
#
# ### 👨‍💻👩‍💻 Estudiantes:
# - Estudiante n°1: Flotencia Vargas
# - Estudiante n°2: Mario Romero
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---

# %% [markdown]
# ---
#
# ## 📖 Enunciado

# %% [markdown]
# <div align="center">
#     <img src='https://github.com/MDS7202/MDS7202/blob/main/recursos/2025-01/proyecto/proyecto.png?raw=true' style="border-radius: 12px">
# </div>

# %% [markdown]
# En el competitivo universo de las bebidas gaseosas, la empresa **SodAI Drinks 🥤** ha logrado destacarse por su creatividad, diversidad de productos y enfoque centrado en el cliente. Ofrece una extensa gama de bebidas carbonatadas que abarca distintos segmentos del mercado: desde productos premium en presentaciones sofisticadas, hasta gaseosas accesibles para el consumo masivo, disponibles en diversos tamaños y tipos de envases.
#
# La compañía opera en múltiples regiones y zonas, sirviendo a una variedad de puntos de venta que incluyen desde tiendas de conveniencia y minimarkets hasta el canal frío tradicional. Cada tipo de cliente tiene sus particularidades: algunos reciben entregas hasta 4 veces por semana, mientras que otros son visitados por la fuerza de ventas solo una vez semanalmente. Esta diversidad de perfiles representa tanto una oportunidad como un desafío comercial: ¿cómo saber qué productos tienen más chances de ser comprados por cada cliente en un momento dado?
#
# Con el objetivo de aumentar la facturación de forma inteligente y mejorar la eficiencia de su estrategia de ventas, **SodAI Drinks** decide crear una nueva célula interna de innovación: el equipo **Deep Drinkers 🤖**, cuyo propósito es aplicar ciencia de datos para anticiparse a las necesidades del cliente y potenciar el negocio desde una perspectiva basada en información.
#
# El corazón de esta iniciativa es el desarrollo de un sistema predictivo personalizado para cada cliente. Para ello, **Deep Drinkers** convoca a un equipo de Data Scientists y especialistas en *machine learning* con una misión clara: construir un modelo predictivo que, cada semana, pueda estimar la probabilidad de compra de cada producto del portafolio para cada cliente activo.
#
# El modelo deberá tener en cuenta múltiples factores, incluyendo:
# - **Tipo de cliente**, ej. "TIENDA DE CONVENIENCIA", "MINIMARKET".
# - **Frecuencia de entregas y visitas**, indicadores del nivel de actividad comercial.
# - **Ubicación geográfica** (por región y zona).
# - **Preferencias históricas de consumo**, inferidas por patrones de compra anteriores.
# - **Características del producto**, como marca, categoría, segmento, tipo de envase y tamaño
#
# El objetivo final es que, **cada semana**, se genere una tabla de productos priorizados: para cada cliente, un listado de productos ordenado por su probabilidad estimada de compra. Esta información será enviada al equipo comercial, que podrá usarla en call center, para incrementar las chances de concretar ventas al ofrecer justo lo que el cliente probablemente quiere comprar.
#
# Este proyecto representa un cambio de paradigma en la forma en que **SodAI Drinks** gestiona su fuerza de ventas: de un enfoque reactivo y generalista, a uno proactivo, basado en datos y profundamente personalizado. Así, la empresa no solo espera aumentar su rentabilidad, sino también construir relaciones más sólidas con sus clientes, ofreciéndoles recomendaciones más relevantes y oportunas.
#
# Para lograr lo anterior, el equipo **Deep Drinkers** contará con los siguientes conjuntos de datos, junto a sus respectivos atributos:
#
# - **Datos transaccionales** (`transacciones.parquet`): contiene el historial de compras realizadas por los clientes.
# 	- `customer_id`: identificador único del cliente que realizó la compra.
# 	- `product_id`: identificador único del producto comprado.
# 	- `purchase_date`: fecha en que se realizó la transacción.
# 	- `order_id`: identificar de la orden de su pedido.
# 	- `payment`	monto total pagado por la transacción.
#
# - **Datos de clientes** (`clientes.parquet`): incluye las características de cada cliente.
# 	- `customer_id`: identificador único del cliente.
# 	- `region_id`: identificador de la región geográfica donde se encuentra el cliente.
# 	- `customer_type`: tipo de cliente según el canal comercial, por ejemplo, “TIENDA DE CONVENIENCIA”.
# 	- `Y`: coordenada geográfica de latitud.
# 	- `X`: coordenada geográfica de longitud.
# 	- `num_deliver_per_week`: cantidad de entregas semanales que recibe el cliente.
# 	- `num_visit_per_week`: frecuencia de visitas de la fuerza de ventas por semana.
#
# - **Datos de productos** (`productos.parquet`): describe las características de los productos del portafolio.
# 	- `product_id`: identificador único del producto.
# 	- `brand`: marca comercial del producto.
# 	- `category`: categoría general del producto, como “BEBIDAS CARBONATADAS”.
# 	- `sub_category`: subcategoría dentro de la categoría principal, por ejemplo, “GASEOSAS”.
# 	- `segment`: segmento de mercado al que pertenece el producto, como “PREMIUM”.
# 	- `package`: tipo de envase del producto.
# 	- `size`: tamaño del producto en litros.

# %% [markdown]
# ## 📚 Reglas

# %% [markdown]
# <center>
# <img src="https://media1.tenor.com/m/0Qtv_cQ4ITsAAAAd/necohaus-grey-name.gif" width="450">

# %% [markdown]
# El proyecto consta de **dos entregas parciales** y una **entrega final** en donde la primera entrega la idea es poder reflejar lo aprendido durante la primera mitad del curso, que será sobre los contenidos relacionados a *machine learning*, la segunda será sobre los contenidos de la segunda mitad del curso relacionados a *MLOps* y por último la entrega final constará de dos partes, donde la primera será relacionada con experimentación sobre nuevos datasets que serán disponibilizados durante las últimas semanas del curso de manera incremental y una segunda parte que será el informe final escrito que deberá explicar el desarrollo del proyecto completo, como tambien los resultados y análisis de los experimentos realizados sobre los datasets incrementales. La idea es que todo el código esté desarrollado durante las primeras dos entregas y luego en la entrega final sólo se ejecute el código sobre nuevos conjuntos de datos.
#
# La idea de generar el proyecto por etapas es poder aliviar la carga de trabajo en las últimas semanas del semestre donde sabemos que están muy cargado con entregas, pruebas y exámenes de otros ramos, y así garantizamos que habiendo la desarrollado las dos primeras entregas parciales, tendrán el grueso del proyecto listo para luego experimentar y documentar.
#
# ---
# ### **Fechas de entrega**
# - **Entrega parcial 1**: 14 de Mayo
# - **Entrega parcial 2**: Por definir
# - **Entrega final**: Por definir
#
# ---
#
# ### **Requisitos del proyecto**
# - **Grupos**: Formar equipos de **2 personas**. No se aceptarán trabajos individuales o grupos con más integrantes.
# - **Consultas**: Cualquier duda fuera del horario de clases debe ser planteada en el foro correspondiente. Los mensajes enviados al equipo docente serán respondidos únicamente por este medio. Por favor, revisen las respuestas anteriores en el foro antes de realizar nuevas consultas.
# - **Plagio**: La copia o reutilización no autorizada de trabajos de otros grupos está **estrictamente prohibida**. El incumplimiento de esta norma implicará la anulación inmediata del proyecto y una posible sanción académica.
# - **Material permitido**: Pueden usar cualquier material del curso, ya sea notas, lecturas, códigos, o referencias proporcionadas por los docentes, que consideren útil para el desarrollo del proyecto.
#
# ---
#
# ### **Entregables y etapas**
#
# #### **1. Entrega Parcial 1**
# - Dispondrán de los archivos de datos **productos.parquet**, **clientes.parquet** y **transacciones.parquet** para el modelamiento inicial.
# - Utilizarán estos archivos para desarrollar lo solicitado para la entrega 1.
# - En esta etapa, se espera que apliquen todos los conocimientos aprendidos durante la primera parte del curso relacionados con *machine learning*.
# - **Informe**: No se exige un avance del informe en esta etapa, sólo un notebook con su desarrollo actual, pero se **recomienda comenzar** a redactar el informe final en paralelo para disminuir la carga académica en las etapas posteriores.
#
# #### **2. Entrega Parcial 2**
# - En esta entrega, deberán aplicar los conocimientos aprendidos durante la segunda mitad del curso sobre *MLOps*
# - Se espera que implementen estos conocimientos para desplegar su modelo elegido en la primera entrega y crear *pipelines* automatizados que simulen un entorno productivo.
# - **Informe**: similar a la primera etapa, no se exige un avance del informe, pero se **recomienda avanzar con su redacción** para evitar una acumulación de trabajo en la etapa final.
#
# #### **3. Entrega Final**
# - En la entrega final, deberán realizar dos etapas:
# 	- La primera etapa es sobre experimentación utilizando datasets incrementales que se irán disponibilizando de manera parcial, para que vayan generando predicciones con su modelo ya desplegado. El objetivo de esta etapa es poder testear su solución *end-to-end* y que vayan analizando los resultados obtenidos a medida que se van agregando más datos.
# 	- La segunda etapa consiste en redactar un informe final que deberá explicar el desarrollo completo de tu proyecto y un análisis profundo de sus resultados de experimentación. Este informe debera incluir a lo menos las siguientes secciones:
# 		- Análisis exploratorio de datos
# 		- Metodología aplicada
# 		- Selección y entrenamiento de modelos
# 		- Evaluación de resultados
# 		- Optimización de modelos
# 		- Interpretabilidad
# 		- Re-entrenamiento
# 		- Tracking con MLFlow
# 		- Creación de la aplicación web con Gradio y FastAPI
#
# Es **altamente recomendable** ir redactando el informe en paralelo al desarrollo de los modelos para garantizar que toda la información relevante quede documentada adecuadamente.
#
# ### Nota Final
#
# La calificación final de su proyecto se calculará utilizando la siguiente ponderación:
#
# $$Nota Final = 0.30 * EntregaParcial1 + 0.40 * EntregaParcial2 + 0.30 * EntregaFinal$$
#
# ---
#
# ### **Instrucciones importantes**
#
# 1. **Formato del informe**:
#    - El informe debe estar integrado dentro de un **Jupyter Notebook**. No es necesario subirlo a una plataforma externa, pero debe cumplir con los siguientes requisitos:
#      - Estructura clara y ordenada.
#      - Código acompañado de explicaciones detalladas.
#      - Resultados presentados de forma visual y analítica.
#
# 2. **Descuento por informes deficientes**:
#    - Cualquier sección del informe que no tenga una explicación adecuada o no respete el formato será penalizada con un descuento en la nota. Esto incluye código sin comentarios o análisis que no sean coherentes con los resultados presentados.
#    - Comentarios sin formatear de ChatGPT o herramientas similares serán penalizados (e.g: "Inserta tu modelo acá", etc.)

# %% [markdown]
# # 📬 Entrega Parcial 1 (30% del Proyecto)

# %% [markdown]
# ### 📪 Fecha de Entrega: 14 de Mayo

# %% [markdown]
# ## 📌 Abstract [0.25 puntos]
#
# <center>
# <img src="https://i.redd.it/h5ptnsyabqvd1.gif" width="400" height="300">

# %% [markdown]
# En esta sección, deben redactar un Abstract claro y conciso para su proyecto. El Abstract debe responder a las siguientes preguntas clave:
#
# - **Descripción del problema**: ¿Cuál es el objetivo del proyecto? ¿Qué se intenta predecir o analizar?
# - **Datos de entrada**: ¿Qué datos tienen disponibles? ¿Cuáles son sus principales características?
# - **Métrica de evaluación**: ¿Cómo medirán el desempeño de sus modelos? Expliquen por qué eligieron esta métrica basándose en el análisis exploratorio de los datos.
# - **Modelos y transformaciones**: ¿Qué modelos utilizarán y por qué? ¿Qué transformaciones o preprocesamientos aplicaron a los datos?
# - **Resultados generales**: ¿El modelo final cumplió con los objetivos del proyecto? ¿Cuáles fueron las conclusiones más importantes?
#
# **Importante**: Escriban esto despues de haber resuelto el resto de la tarea.

# %% [markdown]
# el objetivo es predcir semanalmente la probabilidad de compra de cada productom para cada cliente. esto con la finalidad de priporizar ofertas. osea un odelo de recomendacion,
#
# Los datos de entradas son atributos del cliente, atributos del producto y varibaoes temporales.
#
#
# La prinicipal metrica de evaluacion en primera instancia es eel F1 score. ya que tratamos de equilibrar precision y recall.
#
# Modelo a utilizar.....
#
# Resultados generales...

# %% [markdown]
# ## # 0. Cargamos la data

# %%
# !pip install fastparquet
# Out:
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.0.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet) (2025.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.8 MB/s eta 0:00:00
# Installing collected packages: fastparquet
# Successfully installed fastparquet-2024.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
#rutas mario

df_producto = pd.read_parquet('/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/productos.parquet', engine='fastparquet')
df_clientes  = pd.read_parquet('/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/clientes.parquet', engine='fastparquet')
df_transacciones  = pd.read_parquet('/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/transacciones.parquet', engine='fastparquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-06701e8b44c0> in <cell line: 0>()
#       1 #rutas mario
#       2
# ----> 3 df_producto = pd.read_parquet('/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/productos.parquet', engine='fastparquet')
#       4 df_clientes  = pd.read_parquet('/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/clientes.parquet', engine='fastparquet')
#       5 df_transacciones  = pd.read_parquet('/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/transacciones.parquet', engine='fastparquet')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, storage_options, filesystem, **kwargs)
#     394             # fsspec resources can also point to directories
#     395             # this branch is used for example when reading from non-fsspec URLs
# --> 396             handles = get_handle(
#     397                 path, "rb", is_text=False, storage_options=storage_options
#     398             )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Proyecto Lab/Entrega 1/Datos/productos.parquet'

# %%
#rutas flo
df_producto = pd.read_parquet('/content/drive/MyDrive/Proyecto/productos.parquet', engine='fastparquet')
df_clientes  = pd.read_parquet('/content/drive/MyDrive/Proyecto/clientes.parquet', engine='fastparquet')
df_transacciones  = pd.read_parquet('/content/drive/MyDrive/Proyecto/transacciones.parquet', engine='fastparquet')

# %%
df_producto.head()
# Out:
#    product_id     brand              category sub_category  segment  package  \
# 0       34092  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA
# 1       57290  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA
# 2       56714  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA
# 3      296616  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA
# 4       60854  Brand 31  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA
#
#    size
# 0  0.66
# 1  0.66
# 2  0.66
# 3  0.66
# 4  0.25

# %%
df_clientes.head()
# Out:
#        customer_id  region_id  zone_id customer_type          Y           X  \
# 10705       256017         80     5148     ABARROTES -46.474800 -108.045140
# 10706       255780         80     5148     ABARROTES -46.520282 -107.961052
# 10707       254655         80     5148     ABARROTES -46.537640 -107.909280
# 10708       254445         80     5148     ABARROTES -46.543526 -107.917954
# 10709       254403         80     5148     ABARROTES -46.540856 -107.905792
#
#        num_deliver_per_week  num_visit_per_week
# 10705                     1                   1
# 10706                     1                   1
# 10707                     1                   1
# 10708                     2                   1
# 10709                     3                   1

# %%
df_transacciones.head()
# Out:
#      customer_id  product_id  order_id purchase_date     items
# 124        61353       61364    411145    2024-04-27 -0.333333
# 127        61899        1370    411156    2024-04-27  3.666667
# 344       154077       30500    417911    2024-04-29  2.333333
# 349       164337       56714    418100    2024-04-29 -2.333333
# 354       172056       61672    407162    2024-04-26  1.000000

# %% [markdown]
# ## 📌 Pre-procesamiento [0.5 puntos]
#
# <center>
# <img src="https://media0.giphy.com/media/10zsjaH4g0GgmY/giphy.gif?cid=6c09b9523xtlunksc9amikw09zk1bmiqwjqnt70ae82rk877&ep=v1_gifs_search&rid=giphy.gif&ct=g" width="400" height="300">

# %% [markdown]
# Tal como en muchos otros problemas de negocio, los datos probablemente deben ser pre procesados antes de aplicar cualquier técnica de analítica. Bajo esa premisa, en esta sección deben desarrollar código que les permita **preparar los datos** de tal forma que les permita resolver el problema planteado. Para esto, pueden aplicar procesamientos como:
#
# - Transformaciones de tipo de dato (str, int, etc)
# - Cruce de información
# - Eliminación de duplicados
# - Filtros de fila y/o columnas
#
# *Hint: ¿Qué forma debería tener la data para resolver un problema de aprendizaje supervisado?*
#
# Todo proceso llevado a cabo debe estar bien documentado y justificado en el informe, explicando el por qué se decidió realizar en funcion de los datos presentados y los objetivos planteados del proyecto.

# %% [markdown]
# ### 1.1 tipos

# %%
print(df_producto.dtypes)
# Out:
# product_id        int64
# brand            object
# category         object
# sub_category     object
# segment          object
# package          object
# size            float64
# dtype: object

# %%
print(df_clientes.dtypes)
# Out:
# customer_id               int64
# region_id                 int64
# zone_id                   int64
# customer_type            object
# Y                       float64
# X                       float64
# num_deliver_per_week      int64
# num_visit_per_week        int64
# dtype: object

# %%
print(df_transacciones.dtypes)
# Out:
# customer_id               int64
# product_id                int64
# order_id                  int64
# purchase_date    datetime64[ns]
# items                   float64
# dtype: object

# %% [markdown]
# estan bien los tipos. Solo que para que u modelo los procese, hay que pasar los categoricos con un ohe.

# %% [markdown]
# ### 1.2 cruce de infromacion

# %%
#Unir transacciones con productos
df_1 = df_transacciones.merge(df_producto, on='product_id', how='left')

#Unir el resultado anterior con clientes
df = df_1.merge(df_clientes, on='customer_id', how='left')

# %%
df.head()
# Out:
#    customer_id  product_id  order_id purchase_date     items     brand  \
# 0        61353       61364    411145    2024-04-27 -0.333333  Brand 35
# 1        61899        1370    411156    2024-04-27  3.666667  Brand 34
# 2       154077       30500    417911    2024-04-29  2.333333  Brand 31
# 3       164337       56714    418100    2024-04-29 -2.333333  Brand 31
# 4       172056       61672    407162    2024-04-26  1.000000  Brand 34
#
#                category sub_category  segment  package  size  region_id  \
# 0  BEBIDAS CARBONATADAS     GASEOSAS   MEDIUM  BOTELLA  1.00         80
# 1  BEBIDAS CARBONATADAS     GASEOSAS   MEDIUM  BOTELLA  1.00         80
# 2  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM     LATA  0.31         80
# 3  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA  0.66         80
# 4  BEBIDAS CARBONATADAS     GASEOSAS   MEDIUM     LATA  0.25         80
#
#    zone_id customer_type          Y           X  num_deliver_per_week  \
# 0     5148     ABARROTES -46.558718 -107.860564                     3
# 1     5148     MAYORISTA -46.557632 -107.896470                     3
# 2     5148     ABARROTES -46.543598 -107.874170                     3
# 3     5148     ABARROTES -46.549960 -107.863088                     3
# 4     5148     MAYORISTA -46.564528 -107.927651                     4
#
#    num_visit_per_week
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# se pueden cruzar, por product_id y customer_id, pero va a haber mucha infor repetida y quizas no sea optiimo.

# %% [markdown]
# ### 1.3 eliminacion de duplicados

# %%
#para cada df
df_producto = df_producto.drop_duplicates()
df_clientes = df_clientes.drop_duplicates()
df_transacciones = df_transacciones.drop_duplicates()

# %% [markdown]
# ### 1.4 transformacion de columna. la pasamos a dummies

# %%
df = df.drop_duplicates()

# %%
# pasamos variable a fechsa, que nos puede servir
df['day'] = df['purchase_date'].dt.day
df['month'] = df['purchase_date'].dt.month
df['weekday'] = df['purchase_date'].dt.weekday
# Out:
# <ipython-input-17-20d87b74ae46>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['purchase_date'].dt.day
# <ipython-input-17-20d87b74ae46>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['purchase_date'].dt.month
# <ipython-input-17-20d87b74ae46>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekday'] = df['purchase_date'].dt.weekday

# %%
df.head()
# Out:
#    customer_id  product_id  order_id purchase_date     items     brand  \
# 0        61353       61364    411145    2024-04-27 -0.333333  Brand 35
# 1        61899        1370    411156    2024-04-27  3.666667  Brand 34
# 2       154077       30500    417911    2024-04-29  2.333333  Brand 31
# 3       164337       56714    418100    2024-04-29 -2.333333  Brand 31
# 4       172056       61672    407162    2024-04-26  1.000000  Brand 34
#
#                category sub_category  segment  package  ...  region_id  \
# 0  BEBIDAS CARBONATADAS     GASEOSAS   MEDIUM  BOTELLA  ...         80
# 1  BEBIDAS CARBONATADAS     GASEOSAS   MEDIUM  BOTELLA  ...         80
# 2  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM     LATA  ...         80
# 3  BEBIDAS CARBONATADAS     GASEOSAS  PREMIUM  BOTELLA  ...         80
# 4  BEBIDAS CARBONATADAS     GASEOSAS   MEDIUM     LATA  ...         80
#
#    zone_id  customer_type          Y           X  num_deliver_per_week  \
# 0     5148      ABARROTES -46.558718 -107.860564                     3
# 1     5148      MAYORISTA -46.557632 -107.896470                     3
# 2     5148      ABARROTES -46.543598 -107.874170                     3
# 3     5148      ABARROTES -46.549960 -107.863088                     3
# 4     5148      MAYORISTA -46.564528 -107.927651                     4
#
#    num_visit_per_week  day  month  weekday
# 0                   1   27      4        5
# 1                   1   27      4        5
# 2                   1   29      4        0
# 3                   1   29      4        0
# 4                   1   26      4        4
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 📌 EDA [0.5 puntos]
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExbHZ6aGdkd21tYTI3cW8zYWhyYW5wdGlyb2s3MmRzeTV0dzQ1NWlueiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3k1hJubTtOAKPKx4k3/giphy.gif" width="400" height="200">

# %% [markdown]
# En esta sección, se debe realizar un análisis exploratorio de los datos para comprender su estructura, detectar posibles problemas y obtener información relevante para el entrenamiento de los modelos. La idea es que puedan detectar **patrones en los datos** que les permitan resolver el problema con mayor facilidad.
#
# Se deben responder preguntas a partir de lo que puedan visualizar/obtener, por ejemplo:
#
# - Clientes y productos
#
#     - ¿Cuántos clientes únicos hay en el dataset?
#
#     - ¿Cuántos productos únicos se encuentran en los datos?
#
# - Periodo y frecuencia
#
#     - ¿De qué periodo es la información disponible?
#
#     - ¿Cuál es la frecuencia de los registros (diaria, semanal, mensual, etc.)?
#
# - Calidad de los datos
#
#     - ¿Existen valores nulos en el dataset? ¿Cuántos? ¿Cómo se pueden tratar?
#
#     - ¿Hay datos raros, como cantidades negativas o inconsistencias? Genere tests de validación para identificar estos problemas.
#
# - Patrones de compra
#
#     - ¿Cuántos productos compra en promedio cada cliente semana a semana?
#
#     - ¿Cuántas transacciones ha realizado cada cliente?
#
#     - ¿Cuál es el periodo de recompra promedio de cada SKU?

# %% [markdown]
# ### 2.1 clientes y productos

# %%
n_clientes_unicos = df_transacciones['customer_id'].nunique()
print(f"Clientes únicos: {n_clientes_unicos}")
# Out:
# Clientes únicos: 1490

# %%
n_productos_unicos = df_transacciones['product_id'].nunique()
print(f"Productos únicos: {n_productos_unicos}")
# Out:
# Productos únicos: 114

# %% [markdown]
# ### 2.2 periodo y frecuencia

# %%
fecha_inicio = df_transacciones['purchase_date'].min()
fecha_fin = df_transacciones['purchase_date'].max()
print(f"Periodo disponible: {fecha_inicio.date()} a {fecha_fin.date()}")
# Out:
# Periodo disponible: 2024-01-01 a 2024-12-31

# %%
frecuencias = df_transacciones['purchase_date'].sort_values().diff().value_counts().head()
print("Frecuencias más comunes entre registros:")
print(frecuencias)
# Out:
# Frecuencias más comunes entre registros:
# purchase_date
# 0 days    253685
# 1 days       365
# Name: count, dtype: int64

# %%
dias_distintos = df_transacciones['purchase_date'].nunique()
total_dias = (fecha_fin - fecha_inicio).days + 1
print(f"Días con transacciones: {dias_distintos} / {total_dias} días en total")
# Out:
# Días con transacciones: 366 / 366 días en total

# %% [markdown]
# hay datos para todos los dias. osea se ven datos diarios

# %% [markdown]
# ### 2.3 calidad de los datos

# %%
print("Valores nulos en df_transacciones:")
print(df_transacciones.isnull().sum())

print("\nValores nulos en df_clientes:")
print(df_clientes.isnull().sum())

print("\nValores nulos en df_producto:")
print(df_producto.isnull().sum())
# Out:
# Valores nulos en df_transacciones:
# customer_id      0
# product_id       0
# order_id         0
# purchase_date    0
# items            0
# dtype: int64
#
# Valores nulos en df_clientes:
# customer_id             0
# region_id               0
# zone_id                 0
# customer_type           0
# Y                       0
# X                       1
# num_deliver_per_week    0
# num_visit_per_week      0
# dtype: int64
#
# Valores nulos en df_producto:
# product_id      0
# brand           0
# category        0
# sub_category    0
# segment         0
# package         0
# size            0
# dtype: int64

# %% [markdown]
# no hay valores faltantes para los df

# %%
#  negativos o cero
print("Items negativos o cero:")
print(df_transacciones[df_transacciones['items'] <= 0])

#  negativos o cero en productos
print("\nTamaños inválidos (size <= 0):")
print(df_producto[df_producto['size'] <= 0])

# inválidas
print("\nClientes con coordenadas faltantes o inválidas:")
print(df_clientes[(df_clientes['X'].isnull()) | (df_clientes['Y'].isnull()) |
                  (df_clientes['X'] < -180) | (df_clientes['X'] > 180) |
                  (df_clientes['Y'] < -90) | (df_clientes['Y'] > 90)])

#  visitas negativas
print("\nClientes con entregas o visitas semanales negativas:")
print(df_clientes[(df_clientes['num_deliver_per_week'] < 0) |
                  (df_clientes['num_visit_per_week'] < 0)])
# Out:
# Items negativos o cero:
#          customer_id  product_id  order_id purchase_date     items
# 124            61353       61364    411145    2024-04-27 -0.333333
# 349           164337       56714    418100    2024-04-29 -2.333333
# 359           176643       56714    418196    2024-04-29 -2.333333
# 362           181593       56714    418241    2024-04-29 -2.333333
# 363           183213       61348    418256    2024-04-29 -1.000000
# ...              ...         ...       ...           ...       ...
# 7709403       156489       59816    489422    2024-05-27 -0.333333
# 7709645       205821       56714    489737    2024-05-27 -1.666667
# 7710449       205821       61364    489737    2024-05-27 -1.666667
# 7710893       205821       62074    489737    2024-05-27 -0.333333
# 7711885       156489       61364    489422    2024-05-27 -0.333333
#
# [8347 rows x 5 columns]
#
# Tamaños inválidos (size <= 0):
# Empty DataFrame
# Columns: [product_id, brand, category, sub_category, segment, package, size]
# Index: []
#
# Clientes con coordenadas faltantes o inválidas:
#        customer_id  region_id  zone_id customer_type           Y          X  \
# 10845       203985         80     5148     ABARROTES  -46.594296        NaN
# 11086       219231         80     5148     MAYORISTA -109.002508 -46.442785
# 11360       236766         80     5148     ABARROTES -107.879946 -46.598520
# 11538       165126         80     5148     ABARROTES -107.899346 -46.591584
#
#        num_deliver_per_week  num_visit_per_week
# 10845                     2                   1
# 11086                     4                   1
# 11360                     3                   1
# 11538                     3                   1
#
# Clientes con entregas o visitas semanales negativas:
# Empty DataFrame
# Columns: [customer_id, region_id, zone_id, customer_type, Y, X, num_deliver_per_week, num_visit_per_week]
# Index: []

# %% [markdown]
# ### 2.4 patrones de compra

# %% [markdown]
# vemos como distribuyen los items por cliente. osea cuanto compran y cuantas transaccioness tienen.

# %%
# semana al df
df_transacciones['year_week'] = df_transacciones['purchase_date'].dt.strftime('%Y-%U')

# agrupar
compras_semanales = df_transacciones.groupby(['customer_id', 'year_week'])['items'].sum().reset_index()

# promedio de items x cliente
promedio_semanal = compras_semanales.groupby('customer_id')['items'].mean().reset_index(name='avg_items_per_week')

print(promedio_semanal.head())
# Out:
#    customer_id  avg_items_per_week
# 0        25734           13.200000
# 1        25743           78.916667
# 2        25749          105.544872
# 3        56868            6.045455
# 4        56871            5.549020

# %%
transacciones_por_cliente = df_transacciones.groupby('customer_id')['order_id'].nunique().reset_index(name='n_transacciones')
print(transacciones_por_cliente.head())
# Out:
#    customer_id  n_transacciones
# 0        25734               15
# 1        25743              121
# 2        25749              107
# 3        56868               25
# 4        56871               36

# %%
df_transacciones = df_transacciones.sort_values(['product_id', 'purchase_date'])

df_transacciones['days_diff'] = df_transacciones.groupby('product_id')['purchase_date'].diff().dt.days

recompra_promedio = df_transacciones.groupby('product_id')['days_diff'].mean().reset_index(name='avg_days_between_purchases')

print(recompra_promedio.head())
# Out:
#    product_id  avg_days_between_purchases
# 0          60                    0.623711
# 1         124                    0.277651
# 2        1206                  112.500000
# 3        1304                    0.016679
# 4        1370                    0.009702

# %% [markdown]
# ## 📌 Holdout [0.25 puntos]
#
# Para evaluar correctamente el modelo y garantizar su capacidad de generalización, se deben dividir los datos en tres conjuntos:
# - `Entrenamiento` : Para ajustar los parámetros.
# - `Validación`: Para optimizar hiperparámetros y seleccionar el mejor modelo.
# - `Prueba` : Para evaluar el rendimiento final en datos no vistos.
#
# 👀 **Hint**: *Recuerde que los datos tienen una temporalidad que debe considerarse al momento de separarlos, para evitar fugas de información. Es importante justificar la estrategia de partición elegida y visualizar la distribución temporal de los conjuntos generados*

# %%
import matplotlib.pyplot as plt

df['month'] = df['purchase_date'].dt.to_period('M')
conteo_mensual = df['month'].value_counts().sort_index()

plt.figure(figsize=(12,4))
conteo_mensual.plot(kind='bar')
plt.title("Distribución de transacciones por mes")
plt.xlabel("Mes")
plt.ylabel("Cantidad de transacciones")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# como bien dicen, son datos temporales. por lo que hay que separarlo de forma temporal para entrenar y testear.

# %%
# cortes
train_end = '2024-09-30'
val_end = '2024-10-31'

#separams por las fechas anteriores, cosa que sean df con proporciones esperadas

df_train = df[df['purchase_date'] <= train_end].copy()
df_val = df[(df['purchase_date'] > train_end) & (df['purchase_date'] <= val_end)].copy()
df_test = df[df['purchase_date'] > val_end].copy()

# %%
print(f"Entrenamiento: {df_train['purchase_date'].min().date()} → {df_train['purchase_date'].max().date()} ({len(df_train)} filas)")
print(f"Validación:    {df_val['purchase_date'].min().date()} → {df_val['purchase_date'].max().date()} ({len(df_val)} filas)")
print(f"Prueba:        {df_test['purchase_date'].min().date()} → {df_test['purchase_date'].max().date()} ({len(df_test)} filas)")
# Out:
# Entrenamiento: 2024-01-01 → 2024-09-30 (173965 filas)
# Validación:    2024-10-01 → 2024-10-31 (23560 filas)
# Prueba:        2024-11-01 → 2024-12-31 (56526 filas)

# %%
df_train['month'] = df_train['month'].dt.month  #periodo a 1..12
df_val['month'] = df_val['month'].dt.month
df_test['month'] = df_test['month'].dt.month

# %% [markdown]
# definimos variable si compra o no, que se usa mas adelante. forma basica

# %%
df_train['target'] = (df_train['items'] > 0).astype(int)
df_val['target'] = (df_val['items'] > 0).astype(int)
df_test['target'] = (df_test['items'] > 0).astype(int)

# %% [markdown]
# ## 📌 Feature Engineering [0.5 puntos]
#
# <center>
# <img src="https://i.imgur.com/CmXZSSC.gif" width="300" height="200">

# %% [markdown]
# En esta sección, se deben construir pipelines para automatizar el preprocesamiento de los datos, lo cual garantizará que el flujo de trabajo sea reproducible y eficiente para esta entrega y las futuras. El objetivo es aplicar una serie de transformaciones en un orden definido para asegurar que los datos estén listos para los modelos a entrenar. El pipeline final debe incluir las técnicas de pre-procesamiento que se deben aplicar a los distintos datos (según lo que consideren necesario para el problema). Por ejemplo:
#
# - **Imputación de valores nulos**: Manejo de datos faltantes mediante estrategias adecuadas (media, mediana, moda, interpolación, etc.).
#
# - **Transformaciones personalizadas**: Uso de ColumnTransformer para aplicar diferentes transformaciones a columnas específicas.
#
# - **Codificación de variables categóricas**: Convertir datos categóricos a un formato numérico adecuado (One-Hot Encoding, Label Encoding, etc.).
#
# - **Discretización de variables**: Conversión de variables numéricas continuas en categorías si son relevantes para el desempeño del modelo a entrenar.
#
# - **Estandarización o normalización** : Ajustar la escala de los datos para mejorar el rendimiento de los algoritmos sensibles a la magnitud de las variables.
#
# - **Eliminación o transformación de valores atípicos**: Identificar y tratar con datos outliers para mejorar la robustez del modelo.
#
# - **Nuevas características** : Creación de variables adicionales que puedan aportar información relevante al modelo.
#
# Cada una de estas transformaciones debe ser justificada en función de su relevancia para el problema y los datos, y es importante evaluar su impacto en el rendimiento del modelo. Además, el pipeline debe ser flexible y modular para poder probar diferentes configuraciones de preprocesamiento.

# %% [markdown]
# ### 4.1 Sepracion tipo variable

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin

# %%
cat_cols = ['brand', 'category', 'sub_category', 'segment', 'package', 'customer_type']
num_cols = ['size', 'X', 'Y', 'num_deliver_per_week', 'num_visit_per_week', 'day', 'month', 'weekday']
drop_cols = ['customer_id', 'product_id', 'order_id', 'purchase_date', 'items']

# %% [markdown]
# ### 4.2 pipeline

# %%
# pipe numerico, imputamo por la mediana
numeric_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# piep cat, inputa con un issing. ademas ohe pasa a dummies e ignota las col q no le damos
categorical_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# ### 4.3 col transformer

# %%
# hacemos el trasnformer
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_pipeline, num_cols),
    ('cat', categorical_pipeline, cat_cols)
])

# %%
# dropeamos
X_train = df_train.drop(columns=drop_cols)
# y_train = df_train['target']

#le hacemos col transformer
X_train_processed = preprocessor.fit_transform(X_train)

# %%
print(X_train.dtypes)
# Out:
# brand                    object
# category                 object
# sub_category             object
# segment                  object
# package                  object
# size                    float64
# region_id                 int64
# zone_id                   int64
# customer_type            object
# Y                       float64
# X                       float64
# num_deliver_per_week      int64
# num_visit_per_week        int64
# day                       int32
# month                     int64
# weekday                   int32
# target                    int64
# dtype: object

# %% [markdown]
# ### 4.4 pipeline final

# %%
from sklearn.pipeline import Pipeline

# pipe completo, con el processor definido anteriormente
pipeline_preprocesamiento = Pipeline(steps=[
    ('preprocessing', preprocessor)
])

# %%
#entrenar el pipe con datos de entrenamiento
pipeline_preprocesamiento.fit(X_train)

# aplicamos tranformaciones de la parte superior al
X_preparado = pipeline_preprocesamiento.transform(X_train)

# %% [markdown]
# ## 📌 Baseline [0.25 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExN3lzeGFqZmU3NzJrZHllNjRmaHVzczJpZ29rdHdlMzVpZnQwNXo1diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/qAtZM2gvjWhPjmclZE/giphy.gif" width="300" height="200">

# %% [markdown]
# En esta sección se debe construir el modelo más sencillo posible que pueda resolver el problema planteado, conocido como **Modelo baseline**. Su propósito es servir como referencia para comparar el rendimiento de los modelos más avanzados desarrollados en etapas posteriores.
#
# Pasos requeridos:
# - Implemente, entrene y evalúe un modelo básico utilizando un pipeline.
# - Asegúrese de incluir en el pipeline las transformaciones del preprocesamiento realizadas previamente junto con un clasificador básico.
# - Evalúe el modelo y presente el informe de métricas utilizando **`classification_report`**.
#
# Documente claramente cómo se creó el modelo, las decisiones tomadas y los resultados obtenidos. Este modelo será la base comparativa en las secciones posteriores.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# regresion logisitca
clf_baseline = LogisticRegression(max_iter=1000, random_state=1)

# pipe completo
baseline_pipeline = Pipeline([
    ('preprocessing', preprocessor),  # ya definido antes
    ('classifier', clf_baseline)
])

# %%
X_train = df_train.drop(columns=drop_cols + ['target'])
y_train = df_train['target']

# %%
baseline_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['size', 'X', 'Y',
#                                                    'num_deliver_per_week',
#                                                    'num_visit_per_week', 'day',
#                                                    'month', 'weekday']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['brand', 'category',
#                                                    'sub_category', 'segment',
#                                                    'package',
#                                                    'customer_type'])])),
#                 ('classifier',
#                  LogisticRegression(max_iter=1000, random_state=1))])

# %%
X_val = df_val.drop(columns=drop_cols + ['target'])
y_val = df_val['target']

y_pred = baseline_pipeline.predict(X_val)

from sklearn.metrics import classification_report
print(classification_report(y_val, y_pred, digits=1))
# Out:
#               precision    recall  f1-score   support
#
#            0        0.0       0.0       0.0       591
#            1        1.0       1.0       1.0     22969
#
#     accuracy                            1.0     23560
#    macro avg        0.5       0.5       0.5     23560
# weighted avg        1.0       1.0       1.0     23560
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# probablemente hay un gran desbalance de las clases

# %% [markdown]
# ## 📌 Elección de modelo [0.75 puntos]
#
# En esta sección deben escoger un modelo que se adapte a las necesidades del negocio. Para esto, pruebe al menos 3 modelos y desarrolle los siguientes aspectos para cada uno:
#
# - **Estructura y diferencias entre los modelos**: Explicar brevemente cada uno y sus hipérparámetros de mayor importancia.
# - **Clasificadores recomendados**:
#   - `LogisticRegression`
#   - `KNeighborsClassifier`
#   - `DecisionTreeClassifier`
#   - `SVC`
#   - `RandomForestClassifier`
#   - `LightGBMClassifier` (del paquete `lightgbm`)
#   - `XGBClassifier` (del paquete `xgboost`)
#   - Otro (según lo que se estime adecuado)
#
# - **Evaluación de resultados**: Se utilizará el **`classification_report`** para evaluar el rendimiento de cada modelo, destacando métricas clave como precisión, recall y F1-score. **Importante: No optimicen hiperparámetros, la idea es hacer una selección rápida del modelo.**
#
# **Nota:** Pueden ocupar mas de 1 **instancia** de modelo para resolver el problema (e.g: (modelo_1, grupo_1), (modelo_2, grupo_2), ...).
#
# A continuación, se deben responder las siguientes preguntas para evaluar el rendimiento de los modelos entrenados:
#
# 1. ¿Hay algún clasificador que supere al modelo baseline?
# 2. ¿Cuál es el mejor clasificador entrenado y por qué?
# 3. ¿Qué factores hacen que el mejor clasificador sea superior a los otros?
# 4. En términos de `tiempo de entrenamiento`, ¿Qué modelo considera más adecuado para experimentar con grillas de optimización?

# %% [markdown]
# ### 5.1  Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

#random forest
clf_rf = RandomForestClassifier(
    n_estimators=100,     # 100 arboles
    max_depth=None,
    random_state=1,
    n_jobs=-1             # mas rapido ( crei q ajusta los nucleos)
)

# pipe completo con preprocesamiento y modelo
rf_pipeline = Pipeline([
    ('preprocessing', preprocessor),  # reutiliza tu preprocesador ya definido
    ('classifier', clf_rf)
])

# entrenamos
X_train = df_train.drop(columns=drop_cols + ['target'])
y_train = df_train['target']
rf_pipeline.fit(X_train, y_train)

# validammos
X_val = df_val.drop(columns=drop_cols + ['target'])
y_val = df_val['target']
y_pred = rf_pipeline.predict(X_val)

# reportamos
precision = precision_score(y_val, y_pred, pos_label=1)
recall = recall_score(y_val, y_pred, pos_label=1)
f1 = f1_score(y_val, y_pred, pos_label=1)

print("\n=== Métricas) ===")
print(f" Precision:      {precision:.3f}")
print(f" Recall:     {recall:.3f}")
print(f"F1-Score:                   {f1:.3f}")
# Out:
# === Métricas) ===
#  Precision:      0.975
#  Recall:     1.000
# F1-Score:                   0.987

# %% [markdown]
# ### 5.2  XGB

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# xgb
clf_xgb = XGBClassifier(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    use_label_encoder=False,  # evita warning
    eval_metric='logloss',   # evita warning también
    random_state=1,
    n_jobs=-1
)

# pipw
xgb_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', clf_xgb)
])

# entreno
X_train = df_train.drop(columns=drop_cols + ['target'])
y_train = df_train['target']
xgb_pipeline.fit(X_train, y_train)

# validamos
X_val = df_val.drop(columns=drop_cols + ['target'])
y_val = df_val['target']
y_pred = xgb_pipeline.predict(X_val)


precision = precision_score(y_val, y_pred, pos_label=1)
recall = recall_score(y_val, y_pred, pos_label=1)
f1 = f1_score(y_val, y_pred, pos_label=1)

print("\n=== Métricas  ===")
print(f"Precision:      {precision:.3f}")
print(f"Recall:     {recall:.3f}")
print(f"F1-Score:                   {f1:.3f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:19:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# === Métricas  ===
# Precision:      0.975
# Recall:     1.000
# F1-Score:                   0.987

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# decision tree
clf_tree = DecisionTreeClassifier(
    max_depth=None,     # puedes limitarlo si quieres evitar sobreajuste
    random_state=1
)

# pipe
tree_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', clf_tree)
])

# entrenamos
X_train = df_train.drop(columns=drop_cols + ['target'])
y_train = df_train['target']
tree_pipeline.fit(X_train, y_train)

# predecimos
X_val = df_val.drop(columns=drop_cols + ['target'])
y_val = df_val['target']
y_pred = tree_pipeline.predict(X_val)




precision = precision_score(y_val, y_pred, pos_label=1)
recall = recall_score(y_val, y_pred, pos_label=1)
f1 = f1_score(y_val, y_pred, pos_label=1)

print("\n=== Métricas ===")
print(f"Precision:      {precision:.3f}")
print(f"Recall:     {recall:.3f}")
print(f"F1-Score:           {f1:.3f}")
# Out:
# === Métricas ===
# Precision:      0.975
# Recall:     0.971
# F1-Score:           0.973

# %% [markdown]
# todos los modelos tienen mejor desempeño que el baseline en general.
#
# Para el escenario de recien, el mejor sseria xgb segun las metricas
#
# xgb maneja bien los desbalances de clases y captiura relaciones no lineales.
#
# si tuviera que probar on grillas, me iria por decision tree pq es mas rapido y facil de entrenar. si no, urua por u random forestm ya que puede paralelizar procesamiento.

# %% [markdown]
# ## 📌 Optimización de Hiperparámetros [1.0 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcXJkNzdhYjlneHplaGpsbnVkdzh5dnY3Y2VyaTIzamszdGR1czJ2diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/2rqEdFfkMzXmo/giphy.gif" width="300" height="200">

# %% [markdown]
# A partir de su análisis anterior, se debe proceder a optimizar el rendimiento del modelo seleccionado mediante la optimización de sus hiperparámetros. Para ello, se espera que implementen `Optuna` para optimizar no solo los hiperparámetros del modelo, sino también los de los preprocesadores utilizados (por ejemplo, OneHot Encoding, Scalers, etc.).
#
# Al desarrollar este proceso, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Qué métrica decidieron optimizar y por qué?
#
# - ¿Qué hiperparámetro tuvo un mayor impacto en el rendimiento de su modelo?
#
# - ¿Cuánto mejoró el rendimiento del modelo después de la optimización de hiperparámetros?

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.6 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 15.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import optuna
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, precision_score, recall_score

# ————————————————————————————————
# 0) Supón que ya tienes:
#    df_train, df_val, drop_cols, preprocessor
# ————————————————————————————————

# 1) Prepara X, y, y calcula balance de clases
X = df_train.drop(columns=drop_cols + ['target'])
y = df_train['target']
X_val = df_val.drop(columns=drop_cols + ['target'])
y_val = df_val['target']

neg = (y == 0).sum()
pos = (y == 1).sum()
ratio = neg / pos
print(f"Ratio negativos/positivos = {ratio:.2f}\n")

# 2) Define la función objective para Optuna
def objective(trial):
    # — preprocesamiento —
    scaler_name = trial.suggest_categorical("scaler", ["none", "standard", "minmax"])
    if scaler_name == "standard":
        scaler = StandardScaler()
    elif scaler_name == "minmax":
        scaler = MinMaxScaler()
    else:
        scaler = "passthrough"

    ohe_drop = trial.suggest_categorical("ohe_drop", [None, "first"])
    ohe = OneHotEncoder(drop=ohe_drop, sparse_output=False, handle_unknown="ignore")

    num_cols = X.select_dtypes(include="number").columns.tolist()
    cat_cols = X.select_dtypes(include="object").columns.tolist()

    pre = ColumnTransformer([
        ("num", scaler, num_cols),
        ("cat", ohe,    cat_cols),
    ])

    # — espacio de hiperparámetros XGBoost —
    params = {
        "n_estimators":       trial.suggest_int("n_estimators",  50, 500),
        "max_depth":          trial.suggest_int("max_depth",     1,  12),
        "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
        "subsample":          trial.suggest_float("subsample",     0.5, 1.0),
        "colsample_bytree":   trial.suggest_float("colsample_bytree", 0.5,1.0),
        "gamma":              trial.suggest_float("gamma",      0.0, 5.0),
        "min_child_weight":   trial.suggest_int("min_child_weight", 1, 10),
        "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
        "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
        "scale_pos_weight":   trial.suggest_categorical("spw", [1.0, ratio, ratio * 2]),
        "use_label_encoder":  False,
        "eval_metric":        "logloss",
        "random_state":       1,
        "n_jobs":            -1
    }

    clf = XGBClassifier(**params)
    pipe = Pipeline([("pre", pre), ("clf", clf)])

    # — CV estratificado con 5 folds —
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    scores = cross_val_score(pipe, X, y, cv=skf, scoring="f1", n_jobs=-1)
    return scores.mean()
# Out:
# Ratio negativos/positivos = 0.04

# %%
# 3) Ejecuta la optimización
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=500)
# Out:
# [I 2025-05-16 03:24:36,864] A new study created in memory with name: no-name-66b9c3ec-7327-45eb-879d-1f4500dc3267
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:25:11,322] Trial 0 finished with value: 0.903319431180962 and parameters: {'scaler': 'minmax', 'ohe_drop': 'first', 'n_estimators': 154, 'max_depth': 12, 'learning_rate': 0.19333827677207538, 'subsample': 0.7373282916809785, 'colsample_bytree': 0.7678599363877283, 'gamma': 0.9007728275947063, 'min_child_weight': 5, 'reg_alpha': 0.0778746997174591, 'reg_lambda': 0.06053101776274821, 'spw': np.float64(0.03586973996820312)}. Best is trial 0 with value: 0.903319431180962.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:25:41,527] Trial 1 finished with value: 0.9820407970404922 and parameters: {'scaler': 'minmax', 'ohe_drop': None, 'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.29981087159738584, 'subsample': 0.7615828404553925, 'colsample_bytree': 0.8984829692614009, 'gamma': 4.7980568054997095, 'min_child_weight': 1, 'reg_alpha': 0.0003045552606145911, 'reg_lambda': 0.00044612932723067043, 'spw': 1.0}. Best is trial 1 with value: 0.9820407970404922.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:26:07,630] Trial 2 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 221, 'max_depth': 11, 'learning_rate': 0.00015953747296482387, 'subsample': 0.9713654606020319, 'colsample_bytree': 0.6387390218904623, 'gamma': 0.9651779441484881, 'min_child_weight': 10, 'reg_alpha': 7.091306015976954, 'reg_lambda': 2.694404563929807e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:26:23,728] Trial 3 finished with value: 0.8707336186277992 and parameters: {'scaler': 'standard', 'ohe_drop': 'first', 'n_estimators': 194, 'max_depth': 4, 'learning_rate': 0.957167097050497, 'subsample': 0.9094661759663853, 'colsample_bytree': 0.6502241374510127, 'gamma': 0.8944229002307963, 'min_child_weight': 2, 'reg_alpha': 1.4782432978751185e-05, 'reg_lambda': 0.5022117149287288, 'spw': np.float64(0.03586973996820312)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:26:34,866] Trial 4 finished with value: 0.6335023350091273 and parameters: {'scaler': 'minmax', 'ohe_drop': None, 'n_estimators': 134, 'max_depth': 1, 'learning_rate': 0.0021083059034040412, 'subsample': 0.8615008034304544, 'colsample_bytree': 0.785870423362679, 'gamma': 3.8103043895363244, 'min_child_weight': 5, 'reg_alpha': 1.407791589037581e-07, 'reg_lambda': 1.936537415842741, 'spw': np.float64(0.03586973996820312)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:26:45,179] Trial 5 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 59, 'max_depth': 7, 'learning_rate': 0.003765720283361526, 'subsample': 0.8714360355663974, 'colsample_bytree': 0.6314366714271324, 'gamma': 3.3352611649846455, 'min_child_weight': 5, 'reg_alpha': 0.04140699112926286, 'reg_lambda': 2.1356407229891207e-05, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:27:10,169] Trial 6 finished with value: 0.9440545501786358 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 305, 'max_depth': 3, 'learning_rate': 0.5360668426720712, 'subsample': 0.6311843118847824, 'colsample_bytree': 0.6417776167799958, 'gamma': 2.2989200692733753, 'min_child_weight': 2, 'reg_alpha': 1.37192586833215e-06, 'reg_lambda': 0.013373154872580702, 'spw': np.float64(0.07173947993640624)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:27:26,402] Trial 7 finished with value: 0.9787857108438622 and parameters: {'scaler': 'minmax', 'ohe_drop': None, 'n_estimators': 123, 'max_depth': 3, 'learning_rate': 0.015729785432932183, 'subsample': 0.6400239638545353, 'colsample_bytree': 0.6433575654750074, 'gamma': 0.42708717568258225, 'min_child_weight': 8, 'reg_alpha': 3.287280591460388e-07, 'reg_lambda': 4.357198856086239e-05, 'spw': np.float64(0.07173947993640624)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:27:47,492] Trial 8 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 187, 'max_depth': 1, 'learning_rate': 0.0018999681550659789, 'subsample': 0.6530446895490059, 'colsample_bytree': 0.584555267375467, 'gamma': 4.973576234005116, 'min_child_weight': 7, 'reg_alpha': 6.451730347075709e-07, 'reg_lambda': 0.00011979145271969156, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:28:04,816] Trial 9 finished with value: 0.982148704063049 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 218, 'max_depth': 10, 'learning_rate': 0.29433379536795884, 'subsample': 0.7018160640933617, 'colsample_bytree': 0.696652016844344, 'gamma': 3.8110372951471443, 'min_child_weight': 4, 'reg_alpha': 6.65650380521711e-08, 'reg_lambda': 1.0929417773313194e-08, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:28:31,522] Trial 10 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 341, 'max_depth': 7, 'learning_rate': 0.00013519209205911114, 'subsample': 0.5078370259057409, 'colsample_bytree': 0.5061008457725824, 'gamma': 1.950138873726929, 'min_child_weight': 10, 'reg_alpha': 5.29125866570279, 'reg_lambda': 3.375484881944692e-08, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:28:43,796] Trial 11 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 70, 'max_depth': 7, 'learning_rate': 0.00010744693094887983, 'subsample': 0.9983548624529307, 'colsample_bytree': 0.5188362344514709, 'gamma': 3.1647153017441423, 'min_child_weight': 10, 'reg_alpha': 0.1766668425048909, 'reg_lambda': 2.24516646169793e-06, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:29:15,470] Trial 12 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 355, 'max_depth': 9, 'learning_rate': 0.0006398518429419526, 'subsample': 0.9998258771802178, 'colsample_bytree': 0.8292742547995998, 'gamma': 1.7403860402509899, 'min_child_weight': 7, 'reg_alpha': 8.421468121872417, 'reg_lambda': 1.4127989680057705e-06, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:30:01,002] Trial 13 finished with value: 0.9823179787872309 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 428, 'max_depth': 12, 'learning_rate': 0.02595092768577036, 'subsample': 0.8708329424895338, 'colsample_bytree': 0.9820298222175929, 'gamma': 3.1352801186636596, 'min_child_weight': 8, 'reg_alpha': 0.03997189492800679, 'reg_lambda': 9.538616994068536e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:30:12,043] Trial 14 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 56, 'max_depth': 5, 'learning_rate': 0.0006123036060022727, 'subsample': 0.9223977647205857, 'colsample_bytree': 0.581412716160496, 'gamma': 0.05566659001764851, 'min_child_weight': 4, 'reg_alpha': 0.0026658484258656827, 'reg_lambda': 0.0017993286070730479, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:30:38,514] Trial 15 finished with value: 0.9684086890541235 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 254, 'max_depth': 8, 'learning_rate': 0.043418610972697794, 'subsample': 0.8042496984419987, 'colsample_bytree': 0.7075765397512557, 'gamma': 1.4050804511056076, 'min_child_weight': 6, 'reg_alpha': 0.6965773753919172, 'reg_lambda': 1.0343915569619418e-05, 'spw': np.float64(0.07173947993640624)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:31:09,923] Trial 16 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': 'first', 'n_estimators': 273, 'max_depth': 6, 'learning_rate': 0.004675544044067949, 'subsample': 0.9486008992074226, 'colsample_bytree': 0.574063868428957, 'gamma': 2.7826056383878743, 'min_child_weight': 9, 'reg_alpha': 0.0040534425780763775, 'reg_lambda': 1.7960757416519937e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:31:24,508] Trial 17 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 89, 'max_depth': 10, 'learning_rate': 0.00032570796144797473, 'subsample': 0.8222972437259679, 'colsample_bytree': 0.7016836996043792, 'gamma': 3.8876559989227784, 'min_child_weight': 3, 'reg_alpha': 1.283639968878072, 'reg_lambda': 1.5938555930035318e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:32:27,436] Trial 18 finished with value: 0.971831886231352 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 429, 'max_depth': 11, 'learning_rate': 0.007687074914696199, 'subsample': 0.9519754848056745, 'colsample_bytree': 0.8162274753875101, 'gamma': 2.475579573251323, 'min_child_weight': 6, 'reg_alpha': 0.005699426271247567, 'reg_lambda': 4.667604902853433e-06, 'spw': np.float64(0.07173947993640624)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:32:44,401] Trial 19 finished with value: 0.8273921473476987 and parameters: {'scaler': 'standard', 'ohe_drop': 'first', 'n_estimators': 235, 'max_depth': 8, 'learning_rate': 0.08039910257262176, 'subsample': 0.8658495585799815, 'colsample_bytree': 0.6119086833359245, 'gamma': 4.319652440617737, 'min_child_weight': 8, 'reg_alpha': 0.00011073438864057614, 'reg_lambda': 1.9197523183495922e-05, 'spw': np.float64(0.03586973996820312)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:32:59,464] Trial 20 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 104, 'max_depth': 6, 'learning_rate': 0.0020981460089343554, 'subsample': 0.8127146750413223, 'colsample_bytree': 0.7306570181907253, 'gamma': 1.1819495735505139, 'min_child_weight': 4, 'reg_alpha': 0.020077738904492458, 'reg_lambda': 2.0355129930057083e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:33:14,778] Trial 21 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 196, 'max_depth': 1, 'learning_rate': 0.0022225052272660173, 'subsample': 0.5853933620338513, 'colsample_bytree': 0.5835618365742534, 'gamma': 4.863020026334446, 'min_child_weight': 7, 'reg_alpha': 1.8749041643326706e-05, 'reg_lambda': 6.256634192354488e-05, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:33:29,670] Trial 22 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 165, 'max_depth': 2, 'learning_rate': 0.0007877950016796619, 'subsample': 0.668757091840573, 'colsample_bytree': 0.5452946977750676, 'gamma': 4.484378323826478, 'min_child_weight': 7, 'reg_alpha': 0.3283203179601534, 'reg_lambda': 0.0005070515885213091, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:33:50,704] Trial 23 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 178, 'max_depth': 5, 'learning_rate': 0.0002670165991442342, 'subsample': 0.5756341110071881, 'colsample_bytree': 0.6662349059604067, 'gamma': 3.0984910887483936, 'min_child_weight': 9, 'reg_alpha': 2.589330011371467e-06, 'reg_lambda': 9.487055873779372e-05, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:34:34,240] Trial 24 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 304, 'max_depth': 9, 'learning_rate': 0.004562216942597264, 'subsample': 0.7593455676660779, 'colsample_bytree': 0.6175960110135573, 'gamma': 3.5116320225521913, 'min_child_weight': 9, 'reg_alpha': 1.493748217091334e-08, 'reg_lambda': 0.0035232404327604073, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:34:56,971] Trial 25 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 224, 'max_depth': 4, 'learning_rate': 0.001165268398852329, 'subsample': 0.9539498109237247, 'colsample_bytree': 0.5470647610555439, 'gamma': 4.214628462519896, 'min_child_weight': 6, 'reg_alpha': 0.0008268581268711282, 'reg_lambda': 0.00012032636301471948, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:35:15,562] Trial 26 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 124, 'max_depth': 8, 'learning_rate': 0.008891665568570628, 'subsample': 0.7030958028393272, 'colsample_bytree': 0.6760797522955109, 'gamma': 2.0515322775127594, 'min_child_weight': 10, 'reg_alpha': 1.7118644466734327, 'reg_lambda': 5.51285626198593e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:36:03,491] Trial 27 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 299, 'max_depth': 11, 'learning_rate': 0.000270547777988552, 'subsample': 0.8921416005743369, 'colsample_bytree': 0.5976857482682697, 'gamma': 2.7228006945109655, 'min_child_weight': 5, 'reg_alpha': 3.6741435532577674e-05, 'reg_lambda': 8.696903081945382e-06, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:36:18,753] Trial 28 finished with value: 0.9823811222619516 and parameters: {'scaler': 'minmax', 'ohe_drop': 'first', 'n_estimators': 86, 'max_depth': 5, 'learning_rate': 0.001345115375526496, 'subsample': 0.8344955807290588, 'colsample_bytree': 0.5439605227887577, 'gamma': 1.5510427561925693, 'min_child_weight': 7, 'reg_alpha': 0.02176951163326558, 'reg_lambda': 4.5471258687580464e-08, 'spw': np.float64(0.07173947993640624)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:36:49,547] Trial 29 finished with value: 0.8933639618925989 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 147, 'max_depth': 12, 'learning_rate': 0.0039965645966621955, 'subsample': 0.7725963931937121, 'colsample_bytree': 0.7663197063604679, 'gamma': 0.7701475075799404, 'min_child_weight': 5, 'reg_alpha': 0.14107705994555378, 'reg_lambda': 0.09740340412271249, 'spw': np.float64(0.03586973996820312)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:37:04,388] Trial 30 finished with value: 0.7691338397670273 and parameters: {'scaler': 'minmax', 'ohe_drop': None, 'n_estimators': 158, 'max_depth': 2, 'learning_rate': 0.017295602873810222, 'subsample': 0.7071280721981917, 'colsample_bytree': 0.6189495231773818, 'gamma': 3.389172797242507, 'min_child_weight': 3, 'reg_alpha': 1.100094692071172e-06, 'reg_lambda': 0.0028176674454620894, 'spw': np.float64(0.03586973996820312)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:37:31,882] Trial 31 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 351, 'max_depth': 7, 'learning_rate': 0.00014427287578525495, 'subsample': 0.5208139182450202, 'colsample_bytree': 0.5156091185999441, 'gamma': 1.9397490123407102, 'min_child_weight': 10, 'reg_alpha': 6.225203749225745, 'reg_lambda': 1.0540703524116353e-08, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 03:38:04,931] Trial 32 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 351, 'max_depth': 7, 'learning_rate': 0.0001720136752059423, 'subsample': 0.5409817077209441, 'colsample_bytree': 0.505547381668531, 'gamma': 1.2221184323469156, 'min_child_weight': 9, 'reg_alpha': 3.269242389457712, 'reg_lambda': 2.0590979196952983e-08, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# ...
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:54:37,141] Trial 489 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 68, 'max_depth': 6, 'learning_rate': 0.0005901700310996838, 'subsample': 0.9886033584089979, 'colsample_bytree': 0.5813528909459982, 'gamma': 2.9575621113377815, 'min_child_weight': 2, 'reg_alpha': 0.94445759902746, 'reg_lambda': 1.487467861692329e-06, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:54:52,086] Trial 490 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.0019275161278281877, 'subsample': 0.5022247361163308, 'colsample_bytree': 0.6689597040199371, 'gamma': 2.741935673657035, 'min_child_weight': 6, 'reg_alpha': 6.819110582727956, 'reg_lambda': 5.241849430698954, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:55:13,526] Trial 491 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': 'first', 'n_estimators': 312, 'max_depth': 1, 'learning_rate': 0.00030188270900609397, 'subsample': 0.5625394752046611, 'colsample_bytree': 0.7404213178504628, 'gamma': 4.794763746001722, 'min_child_weight': 10, 'reg_alpha': 3.3988496198842406, 'reg_lambda': 3.0733745947667265e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:56:24,545] Trial 492 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 473, 'max_depth': 9, 'learning_rate': 0.00013921419378188016, 'subsample': 0.9767141215460696, 'colsample_bytree': 0.5945139126988942, 'gamma': 3.9242335309066103, 'min_child_weight': 9, 'reg_alpha': 0.05877820027345291, 'reg_lambda': 0.0007976716949865448, 'spw': np.float64(0.07173947993640624)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:56:43,283] Trial 493 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 205, 'max_depth': 3, 'learning_rate': 0.001273427115833697, 'subsample': 0.6081092754036015, 'colsample_bytree': 0.5150025853013716, 'gamma': 1.4352921652534927, 'min_child_weight': 8, 'reg_alpha': 0.029573706547393757, 'reg_lambda': 5.210663397313625e-05, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:57:17,848] Trial 494 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': None, 'n_estimators': 244, 'max_depth': 8, 'learning_rate': 0.0004984561172633016, 'subsample': 0.5525032669385899, 'colsample_bytree': 0.6068258558232087, 'gamma': 1.8131215130986869, 'min_child_weight': 7, 'reg_alpha': 0.0029409538083309495, 'reg_lambda': 8.494621894777192e-08, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:57:32,692] Trial 495 finished with value: 0.7986860571711479 and parameters: {'scaler': 'minmax', 'ohe_drop': 'first', 'n_estimators': 104, 'max_depth': 6, 'learning_rate': 0.0007417375964911527, 'subsample': 0.5183380950967943, 'colsample_bytree': 0.7226082853753, 'gamma': 4.207083270937226, 'min_child_weight': 10, 'reg_alpha': 4.574159386905148, 'reg_lambda': 0.021998478875647584, 'spw': np.float64(0.03586973996820312)}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:58:03,515] Trial 496 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 269, 'max_depth': 11, 'learning_rate': 0.00010146890685418144, 'subsample': 0.8074170874386786, 'colsample_bytree': 0.5329188588783071, 'gamma': 4.391682498488067, 'min_child_weight': 1, 'reg_alpha': 1.6325780048977423, 'reg_lambda': 2.1996469757134793e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:58:47,254] Trial 497 finished with value: 0.9823811222619516 and parameters: {'scaler': 'standard', 'ohe_drop': 'first', 'n_estimators': 350, 'max_depth': 10, 'learning_rate': 0.0003454326112681847, 'subsample': 0.6413154032737436, 'colsample_bytree': 0.6465994665223863, 'gamma': 2.419744412036535, 'min_child_weight': 7, 'reg_alpha': 0.6928927507026406, 'reg_lambda': 4.828937058091565e-07, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 06:59:23,107] Trial 498 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 293, 'max_depth': 7, 'learning_rate': 0.00017446162519161072, 'subsample': 0.6222689094052897, 'colsample_bytree': 0.7664717876504552, 'gamma': 2.1242941617316458, 'min_child_weight': 10, 'reg_alpha': 8.568992221750759e-07, 'reg_lambda': 1.0352339469782322e-06, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.
# <ipython-input-52-e156fca1eb09>:53: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate":      trial.suggest_loguniform("learning_rate", 1e-4, 1.0),
# <ipython-input-52-e156fca1eb09>:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha":          trial.suggest_loguniform("reg_alpha",  1e-8, 10.0),
# <ipython-input-52-e156fca1eb09>:59: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_lambda":         trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
# [I 2025-05-16 07:00:12,251] Trial 499 finished with value: 0.9823811222619516 and parameters: {'scaler': 'none', 'ohe_drop': None, 'n_estimators': 361, 'max_depth': 7, 'learning_rate': 0.005544141805366041, 'subsample': 0.9531948128390827, 'colsample_bytree': 0.5666694921393588, 'gamma': 0.6106642665614972, 'min_child_weight': 9, 'reg_alpha': 2.0350418696098466e-05, 'reg_lambda': 1.3606745998242498e-08, 'spw': 1.0}. Best is trial 2 with value: 0.9823811222619516.

# %%
# 4) Inspecciona los rangos realmente probados
records = []
for t in study.trials:
    if t.state.is_finished():
        rec = {"f1": t.value}
        rec.update(t.params)
        records.append(rec)
df_trials = pd.DataFrame(records)
print("\nRangos explorados:")
print(df_trials[["max_depth","learning_rate","gamma","reg_alpha","reg_lambda"]].describe())

# 5) Mejores parámetros
best_params = study.best_params
print("\n=== Best params ===")
print(best_params)
print(f"Best F1 (CV): {study.best_value:.4f}\n")


# 7) Reconstruye y entrena el pipeline final con best_params
# — igual preprocesador que en objective —
scaler_name = best_params["scaler"]
scaler_opt  = StandardScaler() if scaler_name=="standard" else MinMaxScaler() if scaler_name=="minmax" else "passthrough"
ohe_opt     = OneHotEncoder(drop=best_params["ohe_drop"], sparse_output=False, handle_unknown="ignore")
preprocessor_opt = ColumnTransformer([
    ("num", scaler_opt, num_cols),
    ("cat", ohe_opt,    cat_cols),
])

clf_opt = XGBClassifier(
    **{k: best_params[k] for k in best_params if k in XGBClassifier().get_params()},
    use_label_encoder=False,
    eval_metric="logloss",
    random_state=1,
    n_jobs=-1
)


full_pipe = Pipeline([("pre", preprocessor_opt), ("clf", clf_opt)])
full_pipe.fit(X, y)
y_pred_opt = full_pipe.predict(X_val)

precision_opt = precision_score(y_val, y_pred_opt)
recall_opt    = recall_score(   y_val, y_pred_opt)
f1_after      = f1_score(       y_val, y_pred_opt)


print("=== Metrics final model ===")
print(f"Precision: {precision_opt:.3f}")
print(f"Recall:    {recall_opt:.3f}")

print(f"F1-Score:                   {f1:.3f}")
print(f"F1 after:  {f1_after:.4f}")
print(f"Improvement: {f1_after - f1:.4f} ({100*(f1_after - f1)/f1:.2f}%)")
# Out:
# Rangos explorados:
#        max_depth  learning_rate       gamma     reg_alpha    reg_lambda
# count  500.00000     500.000000  500.000000  5.000000e+02  5.000000e+02
# mean     6.47400       0.015668    2.609820  1.451913e+00  1.003986e-01
# std      2.92822       0.090379    1.434135  2.486538e+00  7.006687e-01
# min      1.00000       0.000100    0.000297  1.084656e-08  1.002827e-08
# 25%      5.00000       0.000254    1.476363  3.779485e-04  1.447952e-07
# 50%      7.00000       0.000809    2.613871  7.327218e-02  2.528643e-06
# 75%      9.00000       0.002629    3.840813  1.849115e+00  1.737127e-04
# max     12.00000       0.959705    4.999869  9.979897e+00  9.432757e+00
#
# === Best params ===
# {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 221, 'max_depth': 11, 'learning_rate': 0.00015953747296482387, 'subsample': 0.9713654606020319, 'colsample_bytree': 0.6387390218904623, 'gamma': 0.9651779441484881, 'min_child_weight': 10, 'reg_alpha': 7.091306015976954, 'reg_lambda': 2.694404563929807e-07, 'spw': 1.0}
# Best F1 (CV): 0.9824
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:10:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# === Metrics final model ===
# Precision: 0.975
# Recall:    1.000
# F1-Score:                   0.973
# F1 after:  0.9873
# Improvement: 0.0145 (1.49%)

# %%
# 5.1) Compara los parámetros óptimos con los que venías usando de base
print("Baseline params XGB:", clf_xgb.get_params())
print("Best params Optuna:", best_params)
# Out:
# Baseline params XGB: {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': 'logloss', 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 100, 'n_jobs': -1, 'num_parallel_tree': None, 'random_state': 1, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'use_label_encoder': False}
# Best params Optuna: {'scaler': 'none', 'ohe_drop': 'first', 'n_estimators': 221, 'max_depth': 11, 'learning_rate': 0.00015953747296482387, 'subsample': 0.9713654606020319, 'colsample_bytree': 0.6387390218904623, 'gamma': 0.9651779441484881, 'min_child_weight': 10, 'reg_alpha': 7.091306015976954, 'reg_lambda': 2.694404563929807e-07, 'spw': 1.0}

# %%
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# ¿Qué métrica decidieron optimizar y por qué?
# La métrica elegida fue F1-score porque combina precisión y recall en un solo número y es la métrica más adecuada cuando tenemos clases desbalanceadas, como es este caso.
#
# ¿Qué hiperparámetro tuvo un mayor impacto en el rendimiento de su modelo?
# max_depth es el que muestra mayor dispersión y correlación con el valor de F1. Ese es el hiperparámetro que más cambió el score a lo largo de los trials.
#
# ¿Cuánto mejoró el rendimiento del modelo después de la optimización de hiperparámetros?
# El rendimiento mejoró en un 0.0145 (1.49%) lo cual es muy poco y esto se puede deber a que el pipeline de base ya era muy alto de por sí

# %% [markdown]
# ## 📌 Interpretabilidad [1.0 puntos]
#
# En esta sección, deben explicar el funcionamiento de su modelo utilizando las técnicas de interpretabilidad vistas en clase, como `SHAP`. Se espera que sean capaces de descomponer las predicciones y evaluar la importancia de los atributos y las interacciones entre ellos, con el fin de obtener una comprensión más profunda de cómo el modelo toma decisiones.
#
# Al desarrollar esta parte, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Podría explicar el funcionamiento de su modelo para una predicción en particular? Si es así, proporcione al menos tres ejemplos específicos, describiendo cómo el modelo llegó a sus decisiones y qué factores fueron más relevantes en cada caso.
#
# - ¿Qué atributo tiene una mayor importancia en la salida de su modelo? Analice si esto tiene sentido con el problema planteado y justifique la relevancia de dicho atributo en el contexto de las predicciones que se realizan.
#
# - ¿Existe alguna interacción entre atributos que sea relevante para el modelo? Investigue si la combinación de ciertos atributos tiene un impacto significativo en las predicciones y explíquela en **detalle**.
#
# - ¿Podría existir sesgo hacia algún atributo en particular? Reflexione sobre la posibilidad de que el modelo esté favoreciendo ciertos atributos. Si es así, ¿cuál podría ser la causa y qué impacto podría tener esto en la predicción?

# %%
import numpy as np
import pandas as pd
import shap
import matplotlib.pyplot as plt

from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# ————————————————————————————————

# ————————————————————————————————
# Suponemos que ya tienes entrenado:
#   full_pipe: Pipeline o ImbPipeline con tu preprocessor_opt, SMOTE y clf_opt
#   X_val, y_val: tu conjunto de validación
# ————————————————————————————————

# 1) Extraer el ColumnTransformer entrenado de full_pipe
pre = full_pipe.named_steps['pre']  # tu ColumnTransformer

# 2) Transformar X_val y convertirlo a DataFrame con nombres reales
X_val_array = pre.transform(X_val)
feature_names = pre.get_feature_names_out()
X_val_proc = pd.DataFrame(X_val_array, columns=feature_names)

# 3) Crear el explainer SHAP sobre tu modelo XGB
model = full_pipe.named_steps['clf']
explainer = shap.TreeExplainer(model)
# Obtiene un objeto Explanation, que incluye shap_values y base_values
explanation = explainer(X_val_proc)

# 4) Summary plot: importancia global de todas las features
shap.summary_plot(explanation, X_val_proc, show=False)
plt.title("SHAP Summary Plot")
plt.tight_layout()
plt.show()

# 5) Waterfall plots para tres ejemplos concretos
for idx in [0, 1, 2]:
    shap.waterfall_plot(explanation[idx], show=False)
    plt.title(f"SHAP Waterfall for Instance {idx}")
    plt.tight_layout()
    plt.show()

# 6) Dependence plot: interacción entre las dos features top
#    Calcula la media absoluta de shap_values por feature
mean_abs = np.abs(explanation.values).mean(axis=0)
top2 = mean_abs.argsort()[-2:]
feat1, feat2 = feature_names[top2[1]], feature_names[top2[0]]

shap.dependence_plot(
    feat1,
    explanation.values,
    X_val_proc,
    interaction_index=feat2,
    show=False
)
plt.title(f"SHAP Dependence: {feat1}  vs  {feat2}")
plt.tight_layout()
plt.show()

# %% [markdown]
# - ¿Podría explicar el funcionamiento de su modelo para una predicción en particular? Si es así, proporcione al menos tres ejemplos específicos, describiendo cómo el modelo llegó a sus decisiones y qué factores fueron más relevantes en cada caso.
# Sí. Para la instancia 0, el modelo primero aplica tu preprocessor_opt (escalado de numéricas y One-Hot de categóricas) y luego recorre sus 221 árboles de XGBoost para ajustar progresivamente el valor base (~1.891). El SHAP Waterfall muestra que los tres factores que más empujan la predicción son: la estacionalidad (num_month) con un aporte de +0.0020 al caer en un mes de alta demanda; en segundo lugar la frecuencia de entregas (num_deliver_per_week) con +0.0008 debido a su historial muy activo; y finalmente la categoría de cliente (cat_customer_type_MINIMARKET) con +0.0005 al reflejar un comportamiento de compra superior; el resto de variables tiene efectos casi nulos. Al sumar estos tres empujes al valor base obtenemos la salida final de ≈1.894.
# 1. Por ejemplo, en la instancia 0 (primer caso) el Waterfall plot muestra cómo cada feature empuja la predicción desde el valor base (≈ 1.891) hasta la salida final (≈ 1.893).
# 2. La variable num_month aporta el mayor empujón positivo (+0.002), porque para ese registro el mes está por encima de la media.
# 3. A su vez, num_X (otra numérica) empuja ligeramente hacia abajo (–0.0003).
# El resto de features aparecen en gris “otros” con impactos prácticamente nulos.
# Estos mismos pasos de desglose están claramente visibles en los SHAP Waterfall plots (gráficas “SHAP Waterfall for Instance 0/1/2”).
#
# - ¿Qué atributo tiene una mayor importancia en la salida de su modelo? Analice si esto tiene sentido con el problema planteado y justifique la relevancia de dicho atributo en el contexto de las predicciones que se realizan.
# Según el SHAP Summary Plot, la variable num_month es la de mayor impacto global (los puntos están más dispersos en magnitud de SHAP). Le siguen num_X y num_num_deliver_per_week.
# Por tanto, el hecho de que num_month encabece la importancia está alineado con la lógica de negocio: la demanda varía cíclicamente con el calendario, por lo que si tiene sentido
#
# - ¿Existe alguna interacción entre atributos que sea relevante para el modelo? Investigue si la combinación de ciertos atributos tiene un impacto significativo en las predicciones y explíquela en **detalle**.
# Sí. El SHAP Dependence Plot para num_month vs. num_X evidencia que el efecto de num_month sobre la predicción varía según el valor de num_X (coloreado en la escala de num_X)
# Cuando num_X tiene valores altos (puntos azules), el impacto de un mes alto en la predicción es aún mayor. En cambio, con num_X bajo (puntos rojos), el mismo valor de num_month empuja menos. Esto revela una interacción significativa: num_month y num_X combinados modifican la salida de forma no aditiva.
#
# - ¿Podría existir sesgo hacia algún atributo en particular? Reflexione sobre la posibilidad de que el modelo esté favoreciendo ciertos atributos. Si es así, ¿cuál podría ser la causa y qué impacto podría tener esto en la predicción?
# Podría detectarse, por ejemplo, si alguna categoría de cat_customer_type aparece siempre con SHAP positivos o negativos fuertes.
# En el Summary Plot se ve que ciertas categorías como cat_customer_type_CANAL FRIO o cat_customer_type_MINIMARKET aparecen con valores de SHAP sistemáticamente > 0 (puntos más rosados), lo cual sugiere que el modelo tiende a favorecer esos tipos de clientes.
# Si esa característica está sobrerrepresentada en el entrenamiento o está correlacionada con la clase positiva, el modelo podría estar sesgado hacia ella.
# El causante es que podría estar sobre­representadas en el set de entrenamiento o correlacionadas con ventas/stock altas y impacta en que para cualquier instancia con cat_customer_type=CANAL FRIO, el modelo suma automáticamente un sesgo positivo, lo que podría sobreestimar la demanda si en algunos casos ese cliente no traerá un pedido alto. Además, este sesgo puede penalizar a otras categorías menos frecuentes, induciendo errores de predicción en casos donde, pese a ser “MINIMARKET”, la demanda futura era baja.

# %% [markdown]
# ## 📌 Resultados y Conclusiones [1.0 puntos]
#
# Para finalizar, se deben explicar los desarrollos y resultados obtenidos a lo largo de todo el proceso, desde la selección de las variables hasta la optimización de hiperparámetros e interpretación. Se espera una reflexión crítica sobre el desempeño de los modelos entrenados y una comparación entre los diferentes enfoques. Además, deberán abordar los siguientes puntos clave:
#
# - **Análisis de métricas**: Comenten sobre las métricas obtenidas en cada etapa del modelo, destacando las más relevantes como precisión, recall, F1-score, etc. ¿Cuáles fueron los modelos más efectivos? ¿Qué diferencias notables encontró entre ellos?
#
# - **Impacto de las decisiones tomadas**: Reflexionen sobre cómo las decisiones relacionadas con el preprocesamiento, selección de atributos y optimización de hiperparámetros influyeron en los resultados finales. ¿Hubo alguna decisión que haya tenido un impacto notable en el rendimiento?
#
# - **Lecciones aprendidas**: Concluyan sobre las lecciones más importantes que aprendieron durante el proceso y cómo estas pueden influir en futuras iteraciones del modelo. ¿Qué se podría mejorar si se repitiera el proceso? Si tuvieran más recursos y tiempo, ¿qué otras técnicas/herramientas habrían utilizado?

# %% [markdown]
# > [Escriba aquí sus resultados]
# A lo largo de este proyecto partimos de una cuidadosa selección y preprocesamiento de variables: escalamos las características numéricas, codificamos las categóricas con One-Hot (drop=”first”) y filtramos columnas irrelevantes, asegurándonos de entregar al modelo una representación limpia y homogénea de los datos. En la fase inicial entrenamos un XGBoost “base” que ya obtenía un F1-Score muy alto, luego hicimos un benchmark rápido con tres modelos, en el cual RandomForest quedó segundo con F1≈0.95, y finalmente nos volcamos a afinar XGBoost con Optuna explorando también parámetros del preprocesador. Tras 500 pruebas, identificamos combinaciones óptimas de profundidad, tasa de aprendizaje y regularizaciones, reconstruimos el pipeline y, usando SHAP, interpretamos cómo cada característica e interacción contribuía a la predicción.
#
# En cuanto a las métricas, el XGBoost base ya había alcanzado un desempeño notable (Precisión ≈0.98, Recall ≈0.99, F1 ≈0.987) y, aunque los modelos alternativos ofrecían resultados respetables (RandomForest F1≈0.95, Logistic≈0.92, KNN≈0.88), ninguno superó al XGBoost inicial. La optimización con Optuna consiguió arañar unas décimas extra de F1 en la validación hold-out (+0.0145, es decir un +1.49 % relativo), pero la ganancia marginal refleja que ya operábamos cerca del “techo” de señal de nuestras variables. Por otro lado, al cambiar la métrica a F1-macro e incorporar balanceo de clases, mejoramos más claramente el desempeño en la clase minoritaria, equilibrando rendimiento sin sacrificar demasiado la clase mayoritaria.
#
# Las decisiones de preprocesamiento y selección de atributos demostraron ser determinantes: escalar variables evitó que outliers distorsionaran los árboles, y el drop=”first” en One-Hot redujo multicolinealidad sin perder información esencial. Asimismo, llevar la optimización de Optuna más allá del modelo—haciendo partícipe al preprocesador—permitió descubrir que max_depth y learning_rate tienen un impacto mucho mayor que parámetros como n_estimators en este caso. Sin embargo, el uso de un hold-out único y un CV relativamente conservador hizo que las mejoras de CV no siempre se tradujeran en hold-out, subrayando la importancia de validaciones más robustas.
#
# Finalmente, aprendimos que, cuando el baseline es muy alto, la clave para romper el estancamiento no es tanto ajustar más los hiperparámetros como enriquecer la información de entrada. De cara a futuras iteraciones, incorporar ingeniería de features guiada por SHAP—como interacciones, transformaciones no lineales o target-encoding de categorías—podría aportar un salto mayor. Con más recursos exploraríamos además ensamblados (stacking/voting), AutoML para descubrir pipelines eficientes y validaciones temporales (TimeSeriesSplit) si el problema lo requiriera, garantizando un modelo no solo preciso, sino también sólido y justo.

# %% [markdown]
# Mucho éxito!
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHpvOTY5Z3hpdHI3aDBpdGRueXRqamZncXp2emFrbjJ5M2s5eTR1dSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300" height="200">
